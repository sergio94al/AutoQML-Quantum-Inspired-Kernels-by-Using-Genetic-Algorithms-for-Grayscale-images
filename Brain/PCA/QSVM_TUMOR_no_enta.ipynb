# %%
from sklearn.preprocessing import MinMaxScaler
import time
from deap import base, creator, tools, algorithms
from joblib import Parallel, delayed
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import EarlyStopping
import os
import copy
import cv2
import torch.distributed as dist
import time
import os
import copy
from torch.utils.data import TensorDataset, DataLoader,Dataset, Sampler
import torch.utils.data as data_utils
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import multiprocessing
import pickle
import dill
from sklearn.preprocessing import StandardScaler

# Plotting
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from skimage import color
from skimage import io
import copy
from PIL import Image
import PIL
import imageio
from sklearn.decomposition import PCA

import skimage
from skimage.transform import resize
# PyTorch
import pandas as pd
from glob import iglob
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
def plot_evo (log):
    gen = log.select('gen')
    fit_min = log.select('min')
    fit_max = log.select('max')
    fit_avg = log.select('media')
    
    fig, ax = plt.subplots()
    ax.plot(gen,fit_min, 'b')
    ax.plot(gen,fit_max, 'r')
    ax.plot(gen,fit_avg, '--k')
    ax.fill_between(gen,fit_min,fit_max, alpha=0.2, facecolor='g')
    ax.set_xlabel('Generation')
    ax.set_ylabel('Accuracy')
    ax.set_ylim([0,1])
    ax.legend(['min','max','avg'])
    plt.grid(True)
    output_dir = r'C:\Users\sergi\Desktop\AUTOQML_CODE\Brain\PCA_No_Entangle'
    myfile = "Evolution_7000_pi8.pdf"
    output_path = os.path.join(output_dir,myfile)
    fig.savefig(output_path, bbox_inches='tight', dpi=250)
    
    
def plot_std (log):
    gen = log.select('gen')
    fit_std = log.select('std')
    fig, ax = plt.subplots()
    ax.plot(gen,fit_std,'^g')
    ax.set_xlabel('Generation')
    ax.set_ylabel('Std_Accuracy')
    ax.set_ylim([0,1])
    ax.legend(['std'])
    plt.grid(True)
    output_dir = r'C:\Users\sergi\Desktop\AUTOQML_CODE\Brain\PCA_No_Entangle'
    myfile = "STD_7000_pi8.pdf"
    output_path = os.path.join(output_dir,myfile)
    fig.savefig(output_path, bbox_inches='tight', dpi=250)

# %%
#Math Part
import multiprocessing
import numpy as np
import pandas as pd
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import normalize
import numpy as np
from sklearn import preprocessing 
#Graph
import matplotlib.pyplot as plt
from deap import algorithms
from deap import base
from deap import benchmarks
from deap.benchmarks.tools import diversity, convergence, hypervolume
from deap import creator
from deap import tools
import importlib
import circuit
import encoding
import qsvm
import fitness
import gsvm
importlib.reload(circuit)
importlib.reload(encoding)
importlib.reload(qsvm)
importlib.reload(fitness)
importlib.reload(gsvm)

import pandas as pd
import time

#- Guardo la funcion main en una funcion para poder hacer el line profiler -
def evol(output="Brain_RESULTS_2000_nq6_qd15.csv"):
    faces = pd.DataFrame([])
    label=[]
    Files = ['NO_1', 'YES_0']
    path = r"C:\Users\sergi\Desktop\AUTOQML_CODE\Brain\PCA_No_Entangle"
    for files in Files:
        cpath = os.path.join(path, files)
        cpath = os.path.join(cpath)
        for img in os.listdir(cpath):
            if cpath[-1] == '0':
                label.append(1)
            else:
                label.append(0)   
            img3 = imageio.imread(os.path.join(cpath, img), pilmode='L')
            img = cv2.resize(img3, (250, 250))
            face = pd.Series(img.flatten())
            faces = faces.append(face,ignore_index=True)
            
    start = time.time()
    pop, pareto, log = gsvm.gsvm(nqubits=6, q_depth=11,X=faces, y=label,
                                     mu=3,lambda_=4, ngen=2000)
    print(f'Simulation finished after {time.time()-start} seconds')
    print(f'\nGenetic-algorithm output ({output})')
    print('generation, individual, gates/qubit, accuracy')
    print('---------------------------------------------')
    with open(output, "w") as f:
        for ide, ind in enumerate(pareto):
            genes=''.join(str(i) for i in list(ind))
            gates, acc = ind.fitness.values
            line = f'{ide},"{genes}",{gates},{acc}'
            f.write(line)
            f.write('\n')
            print(line)
    plot_evo (log)
    plot_std (log)

evol()
# Out:
# multi
# gen	nevals	media  	std      	max     	min
# 0  	3     	0.65625	0.0127578	0.671875	0.640625
# 1  	4     	0.651042	0.0321063	0.6875  	0.609375
# 2  	4     	0.671875	0.0127578	0.6875  	0.65625
# 3  	4     	0.6875  	0.0337539	0.734375	0.65625
# 4  	4     	0.6875  	0.0382733	0.734375	0.640625
# 5  	4     	0.645833	0.0702643	0.734375	0.5625
# 6  	4     	0.645833	0.0702643	0.734375	0.5625
# 7  	4     	0.703125	0.0441942	0.734375	0.640625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 70>()
#      67     plot_evo (log)
#      68     plot_std (log)
# ---> 70 evol()
#
# Input In [3], in evol(output)
#      50         faces = faces.append(face,ignore_index=True)
#      52 start = time.time()
# ---> 53 pop, pareto, log = gsvm.gsvm(nqubits=6, q_depth=11,X=faces, y=label,
#      54                                  mu=3,lambda_=4, ngen=2000)
#      55 print(f'Simulation finished after {time.time()-start} seconds')
#      56 print(f'\nGenetic-algorithm output ({output})')
#
# File ~\Desktop\AUTOQML_CODE\Brain\PCA_No_Entangle\gsvm.py:34, in gsvm(nqubits, q_depth, X, y, mu, lambda_, cxpb, mutpb, ngen, use_pareto, verbose, processes, pool)
#      32 logbook = tools.Logbook()
#      33 pareto = tools.ParetoFront(similar = np.array_equal)
# ---> 34 pop, logbook = algorithms.eaMuPlusLambda(pop, toolbox,
#      35                                          mu, lambda_, cxpb, mutpb, ngen,
#      36                                          stats=stats1,
#      37                                          halloffame=pareto, verbose=verbose)
#      38 pareto.update(pop)
#      39 return pop, pareto, logbook
#
# File ~\miniconda3\envs\pennylane_env\lib\site-packages\deap\algorithms.py:321, in eaMuPlusLambda(population, toolbox, mu, lambda_, cxpb, mutpb, ngen, stats, halloffame, verbose)
#     319 invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#     320 fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
# --> 321 for ind, fit in zip(invalid_ind, fitnesses):
#     322     ind.fitness.values = fit
#     324 # Update the hall of fame with the generated individuals
#
# File ~\Desktop\AUTOQML_CODE\Brain\PCA_No_Entangle\fitness.py:59, in Fitness.__call__(self, POP)
#      58 def __call__(self, POP):
# ---> 59     return self.fitness(POP)
#
# File ~\Desktop\AUTOQML_CODE\Brain\PCA_No_Entangle\fitness.py:70, in Fitness.fitness(self, POP)
#      65 param = int("".join(str(i) for i in Components),2)
#      67 if param < self.X.shape[0] and param >=2:
#      69     training_features, training_labels, test_features, test_labels = \
# ---> 70     Dataset(self.X, self.y) ###normalizamos el dataset
#      72     faces_pca = PCA(n_components=param,svd_solver='randomized',whiten=True)
#      73     faces_pca.fit(training_features)
#
# File ~\Desktop\AUTOQML_CODE\Brain\PCA_No_Entangle\fitness.py:47, in Dataset(X, y, test_size_split)
#      45 minmax_scale = MinMaxScaler((-1, 1)).fit(samples)
#      46 train_sample = minmax_scale.transform(train_sample)
# ---> 47 test_sample = minmax_scale.transform(test_sample)
#      49 return train_sample, train_label, test_sample, test_label
#
# File ~\miniconda3\envs\pennylane_env\lib\site-packages\sklearn\preprocessing\_data.py:508, in MinMaxScaler.transform(self, X)
#     499 X = self._validate_data(
#     500     X,
#     501     copy=self.copy,
#    (...)
#     504     reset=False,
#     505 )
#     507 X *= self.scale_
# --> 508 X += self.min_
#     509 if self.clip:
#     510     np.clip(X, self.feature_range[0], self.feature_range[1], out=X)
#
# KeyboardInterrupt:
